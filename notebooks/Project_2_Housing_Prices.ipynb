# %% [markdown]
# # Project_2_Housing_Prices
#
# Notebook moved from My-projects/Credit_Card_Fraud_Detection to christianirshool-glitch/Housing_Prices as Project_2_Housing_Prices.ipynb. This notebook keeps original content but the repository context has changed to Project_2: Housing_Prices.
#
# Please verify dataset paths and any relative file references before running.
#
# Original source: https://github.com/christianirshool-glitch/My-projects/blob/main/Credit_Card_Fraud_Detection/Project_1_Credit_Fraud_Detection.ipynb
