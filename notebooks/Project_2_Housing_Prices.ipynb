# %% [markdown]
# # Placeholder: Project_2. Housing_Prices
#
# Este notebook es un marcador de posición creado automáticamente para inicializar el repositorio.
#
# Si quieres que suba tu notebook real desde Colab, por favor:
# - Sube el archivo `Project_2. Housing_Prices.ipynb` en este chat, o
# - Comparte un enlace público de descarga directa al `.ipynb` (no sólo la vista de Colab).
#
# También puedes guardar directamente desde Colab: File -> Save a copy in GitHub... y selecciona:
# Repository: `christianirshool-glitch/Housing_Prices`
# Path: `notebooks/Project_2_Housing_Prices.ipynb`
#
# Enlace de Colab que proporcionaste:
# https://colab.research.google.com/drive/1JtNXuxWakXVlJDNSM02qdBRmwYI_iLNt?usp=sharing
